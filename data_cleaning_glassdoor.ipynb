# %%
import pandas as pd
df = pd.read_csv("glassdoor_jobs_datascientist.csv")

# %%
df
# Out:
#      Unnamed: 0                                          Job Title  \
# 0             0                                     Data Scientist
# 1             1                          Healthcare Data Scientist
# 2             2                                     Data Scientist
# 3             3                                     Data Scientist
# 4             4                                     Data Scientist
# ..          ...                                                ...
# 951         951                               Senior Data Engineer
# 952         952  Project Scientist - Auton Lab, Robotics Institute
# 953         953                               Data Science Manager
# 954         954                                      Data Engineer
# 955         955          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 0     $53K-$91K (Glassdoor est.)
# 1    $63K-$112K (Glassdoor est.)
# 2     $80K-$90K (Glassdoor est.)
# ...

# %% [markdown]
# #Problems
# 1. salary estimate
# 2. Location
# 3. job description

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#      Unnamed: 0                                          Job Title  \
# 0             0                                     Data Scientist
# 1             1                          Healthcare Data Scientist
# 2             2                                     Data Scientist
# 3             3                                     Data Scientist
# 4             4                                     Data Scientist
# ..          ...                                                ...
# 951         951                               Senior Data Engineer
# 952         952  Project Scientist - Auton Lab, Robotics Institute
# 953         953                               Data Science Manager
# 954         954                                      Data Engineer
# 955         955          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 0     $53K-$91K (Glassdoor est.)
# 1    $63K-$112K (Glassdoor est.)
# 2     $80K-$90K (Glassdoor est.)
# ...

# %%
df['Salary Estimate'].value_counts()
# Out:
# -1                                  214
# $86K-$143K (Glassdoor est.)           6
# $54K-$115K (Glassdoor est.)           6
# $49K-$113K (Glassdoor est.)           6
# $21-$34 Per Hour(Glassdoor est.)      6
#                                    ...
# $74K-$119K (Glassdoor est.)           1
# $55K-$97K (Glassdoor est.)            1
# $15K-$16K(Employer est.)              1
# $61K-$106K (Glassdoor est.)           1
# $62K-$113K (Glassdoor est.)           1
# Name: Salary Estimate, Length: 417, dtype: int64

# %%
df = df.drop('Unnamed: 0', axis = 'columns')
df
# Out:
#                                              Job Title  \
# 0                                       Data Scientist
# 1                            Healthcare Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 951                               Senior Data Engineer
# 952  Project Scientist - Auton Lab, Robotics Institute
# 953                               Data Science Manager
# 954                                      Data Engineer
# 955          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 0     $53K-$91K (Glassdoor est.)
# 1    $63K-$112K (Glassdoor est.)
# 2     $80K-$90K (Glassdoor est.)
# 3     $56K-$97K (Glassdoor est.)
# 4    $86K-$143K (Glassdoor est.)
# ..                           ...
# 951  $72K-$133K (Glassdoor est.)
# ...

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors'],
#       dtype='object')

# %%
df.Rating.value_counts()
# Out:
#  3.8    75
#  3.7    69
#  3.9    69
#  3.6    56
#  4.0    56
#  3.5    53
#  3.4    47
#  4.4    46
#  3.3    44
#  4.2    41
#  4.3    39
#  4.7    38
#  4.1    37
#  3.2    36
# -1.0    34
#  3.1    30
#  5.0    28
#  2.9    22
#  4.5    19
#  4.6    18
#  2.7    17
#  3.0    17
#  4.8    14
#  2.6    14
#  2.4     8
#  2.8     7
#  2.1     5
#  4.9     4
#  2.3     4
#  2.2     3
#  1.9     3
#  2.5     3
# Name: Rating, dtype: int64

# %%
df1 = df[df['Rating'] >= 0.0]

# %%
df1
# Out:
#                                              Job Title  \
# 0                                       Data Scientist
# 1                            Healthcare Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 951                               Senior Data Engineer
# 952  Project Scientist - Auton Lab, Robotics Institute
# 953                               Data Science Manager
# 954                                      Data Engineer
# 955          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 0     $53K-$91K (Glassdoor est.)
# 1    $63K-$112K (Glassdoor est.)
# 2     $80K-$90K (Glassdoor est.)
# 3     $56K-$97K (Glassdoor est.)
# 4    $86K-$143K (Glassdoor est.)
# ..                           ...
# 951  $72K-$133K (Glassdoor est.)
# ...

# %%
df1['hourly'] = df1['Salary Estimate'].apply(lambda x: 1 if 'per hour' in x.lower() else 0)
df1
# Out:
# C:\Users\pmaheria\AppData\Local\Temp/ipykernel_10712/4184047990.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['hourly'] = df1['Salary Estimate'].apply(lambda x: 1 if 'per hour' in x.lower() else 0)
#                                              Job Title  \
# 0                                       Data Scientist
# 1                            Healthcare Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 951                               Senior Data Engineer
# 952  Project Scientist - Auton Lab, Robotics Institute
# ...

# %%
df1['hourly'].value_counts()
# Out:
# 0    898
# 1     24
# Name: hourly, dtype: int64

# %%
df1['employer_provided'] = df1['Salary Estimate'].apply(lambda x: 1 if 'employer provided salary:' in x.lower() else 0)

df1
# Out:
# C:\Users\pmaheria\AppData\Local\Temp/ipykernel_10712/3111920147.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['employer_provided'] = df1['Salary Estimate'].apply(lambda x: 1 if 'employer provided salary:' in x.lower() else 0)
#                                              Job Title  \
# 0                                       Data Scientist
# 1                            Healthcare Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 951                               Senior Data Engineer
# ...

# %%
df1 = df1[df1['Salary Estimate']!='-1']
df1
# Out:
#                                              Job Title  \
# 0                                       Data Scientist
# 1                            Healthcare Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 950           Sr Scientist, Immuno-Oncology - Oncology
# 951                               Senior Data Engineer
# 952  Project Scientist - Auton Lab, Robotics Institute
# 953                               Data Science Manager
# 955          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 0     $53K-$91K (Glassdoor est.)
# 1    $63K-$112K (Glassdoor est.)
# 2     $80K-$90K (Glassdoor est.)
# 3     $56K-$97K (Glassdoor est.)
# 4    $86K-$143K (Glassdoor est.)
# ..                           ...
# 950  $58K-$111K (Glassdoor est.)
# ...

# %%
salary = df1['Salary Estimate'].apply(lambda x: x.split('(')[0])
salary
# Out:
# 0       $53K-$91K
# 1      $63K-$112K
# 2       $80K-$90K
# 3       $56K-$97K
# 4      $86K-$143K
#           ...
# 950    $58K-$111K
# 951    $72K-$133K
# 952     $56K-$91K
# 953    $95K-$160K
# 955    $61K-$126K
# Name: Salary Estimate, Length: 731, dtype: object

# %%
minus_sal = salary.apply(lambda x: x.replace('K','').replace('$',''))

# %%
minus_sal
# Out:
# 0       53-91
# 1      63-112
# 2       80-90
# 3       56-97
# 4      86-143
#         ...
# 950    58-111
# 951    72-133
# 952     56-91
# 953    95-160
# 955    61-126
# Name: Salary Estimate, Length: 731, dtype: object

# %%
min_hour = minus_sal.apply(lambda x: x.lower().replace('per hour','').replace('employer provided salary:',''))
min_hour = min_hour.apply(lambda x: x.replace(' ',''))
min_hour.value_counts()
# Out:
# 86-143    6
# 54-115    6
# 49-113    6
# 21-34     6
# 81-167    5
#          ..
# 62-114    1
# 74-119    1
# 55-97     1
# 15-16     1
# 62-113    1
# Name: Salary Estimate, Length: 411, dtype: int64

# %%
df1['min_salary'] = min_hour.apply(lambda x: int(x.split('-')[0]))
df1
# Out:
# C:\Users\pmaheria\AppData\Local\Temp/ipykernel_10712/3162766681.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['min_salary'] = min_hour.apply(lambda x: int(x.split('-')[0]))
#                                              Job Title  \
# 0                                       Data Scientist
# 1                            Healthcare Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 950           Sr Scientist, Immuno-Oncology - Oncology
# 951                               Senior Data Engineer
# ...

# %%
df1['max_salary'] = min_hour.apply(lambda x: int(x.split('-')[1]))
df1
# Out:
# C:\Users\pmaheria\AppData\Local\Temp/ipykernel_10712/2759212001.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['max_salary'] = min_hour.apply(lambda x: int(x.split('-')[1]))
#                                              Job Title  \
# 0                                       Data Scientist
# 1                            Healthcare Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 950           Sr Scientist, Immuno-Oncology - Oncology
# 951                               Senior Data Engineer
# ...

# %%
df1['avg_salary'] = (df1['min_salary']+df1['max_salary'])/2
# Out:
# C:\Users\pmaheria\AppData\Local\Temp/ipykernel_10712/2515656813.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['avg_salary'] = (df1['min_salary']+df1['max_salary'])/2

# %%
df1
# Out:
#                                              Job Title  \
# 0                                       Data Scientist
# 1                            Healthcare Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 950           Sr Scientist, Immuno-Oncology - Oncology
# 951                               Senior Data Engineer
# 952  Project Scientist - Auton Lab, Robotics Institute
# 953                               Data Science Manager
# 955          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 0     $53K-$91K (Glassdoor est.)
# 1    $63K-$112K (Glassdoor est.)
# 2     $80K-$90K (Glassdoor est.)
# 3     $56K-$97K (Glassdoor est.)
# 4    $86K-$143K (Glassdoor est.)
# ..                           ...
# 950  $58K-$111K (Glassdoor est.)
# ...

# %%
df1 = df1.drop('Salary Estimate',axis = 'columns')

# %%
df1
# Out:
#                                              Job Title  \
# 0                                       Data Scientist
# 1                            Healthcare Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 950           Sr Scientist, Immuno-Oncology - Oncology
# 951                               Senior Data Engineer
# 952  Project Scientist - Auton Lab, Robotics Institute
# 953                               Data Science Manager
# 955          Research Scientist – Security and Privacy
#
#                                        Job Description  Rating  \
# 0    Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1    What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2    KnowBe4, Inc. is a high growth information sec...     4.8
# ...

# %%
df1['job_state'] = df1['Location'].apply(lambda x: x.split(',')[1])
df1.job_state.value_counts()
# Out:
#  CA             148
#  MA              96
#  NY              71
#  VA              41
#  IL              40
#  MD              35
#  PA              33
#  TX              28
#  WA              21
#  NC              21
#  NJ              17
#  FL              16
#  OH              14
#  TN              13
#  DC              11
#  CO              11
#  WI              10
#  IN              10
#  UT              10
#  AZ               9
#  MO               9
#  AL               8
#  GA               6
#  KY               6
#  DE               6
#  MI               6
#  CT               5
#  IA               5
#  LA               4
#  OR               4
#  NE               4
#  NM               3
#  KS               3
#  ID               2
#  MN               2
#  Los Angeles      1
#  RI               1
#  SC               1
# Name: job_state, dtype: int64

# %%
df1['Founded'].value_counts()
# Out:
# -1       41
#  2010    32
#  2008    31
#  1996    27
#  2006    24
#          ..
#  1860     1
#  1942     1
#  1878     1
#  1971     1
#  1889     1
# Name: Founded, Length: 102, dtype: int64

# %%
df1['age'] = df1['Founded'].apply(lambda x: x if x <1 else 2020 - x)

# %%
df1
# Out:
#                                              Job Title  \
# 0                                       Data Scientist
# 1                            Healthcare Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 950           Sr Scientist, Immuno-Oncology - Oncology
# 951                               Senior Data Engineer
# 952  Project Scientist - Auton Lab, Robotics Institute
# 953                               Data Science Manager
# 955          Research Scientist – Security and Privacy
#
#                                        Job Description  Rating  \
# 0    Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1    What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2    KnowBe4, Inc. is a high growth information sec...     4.8
# ...

# %%
df['company_txt'] = df.apply(lambda x: x['Company Name'] if x['Rating'] <0 else x['Company Name'][:-3], axis = 1)

# %%
df1
# Out:
#                                              Job Title  \
# 0                                       Data Scientist
# 1                            Healthcare Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 950           Sr Scientist, Immuno-Oncology - Oncology
# 951                               Senior Data Engineer
# 952  Project Scientist - Auton Lab, Robotics Institute
# 953                               Data Science Manager
# 955          Research Scientist – Security and Privacy
#
#                                        Job Description  Rating  \
# 0    Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1    What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2    KnowBe4, Inc. is a high growth information sec...     4.8
# ...

# %%
df1['python_yn'] = df1['Job Description'].apply(lambda x: 1 if 'python' in x.lower() else 0)
df1['python_yn'].value_counts()
# Out:
# 1    388
# 0    343
# Name: python_yn, dtype: int64

# %%
 
df1['R_yn'] = df1['Job Description'].apply(lambda x: 1 if 'r studio' in x.lower() or 'r-studio' in x.lower() else 0)
df1.R_yn.value_counts()
# Out:
# 0    729
# 1      2
# Name: R_yn, dtype: int64

# %%
df1['spark'] = df1['Job Description'].apply(lambda x: 1 if 'spark' in x.lower() else 0)
df1.spark.value_counts()
# Out:
# 0    564
# 1    167
# Name: spark, dtype: int64

# %%
#aws 
df1['aws'] = df1['Job Description'].apply(lambda x: 1 if 'aws' in x.lower() else 0)
df1.aws.value_counts()
# Out:
# 0    557
# 1    174
# Name: aws, dtype: int64

# %%
#excel
df1['excel'] = df1['Job Description'].apply(lambda x: 1 if 'excel' in x.lower() else 0)
df1.excel.value_counts()
# Out:
# 1    381
# 0    350
# Name: excel, dtype: int64

# %% [markdown]
# # Data visualization and transformation

# %%
def title_rename(title):
    if 'data scientist' in title.lower():
        return 'data scientist'
    elif 'data engineer' in title.lower():
        return 'data engineer'
    elif 'analyst' in title.lower():
        return 'analyst'
    elif 'machine learning' in title.lower():
        return 'mle'
    elif 'manager' in title.lower():
        return 'manager'
    elif 'director' in title.lower():
        return 'director'
    else:
        return 'na'
    
def seniority_level(title):
    if 'sr' in title.lower() or 'senior' in title.lower() or 'sr' in title.lower() or 'lead' in title.lower() or 'principal' in title.lower():
            return 'senior'
    elif 'jr' in title.lower() or 'jr.' in title.lower():
        return 'jr'
    else:
        return 'na'

# %%
df1['job_rename'] = df1['Job Title'].apply(title_rename)

# %%
df1.job_rename.value_counts()
# Out:
# data scientist    276
# na                176
# data engineer     119
# analyst           102
# manager            22
# mle                22
# director           14
# Name: job_rename, dtype: int64

# %%
df1['seniority'] = df1['Job Title'].apply(seniority_level)
df1.seniority.value_counts()
# Out:
# na        515
# senior    214
# jr          2
# Name: seniority, dtype: int64

# %%
df1
# Out:
#                                              Job Title  \
# 0                                       Data Scientist
# 1                            Healthcare Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 950           Sr Scientist, Immuno-Oncology - Oncology
# 951                               Senior Data Engineer
# 952  Project Scientist - Auton Lab, Robotics Institute
# 953                               Data Science Manager
# 955          Research Scientist – Security and Privacy
#
#                                        Job Description  Rating  \
# 0    Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1    What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2    KnowBe4, Inc. is a high growth information sec...     4.8
# ...

# %%
df1['min_salary'] = df1.apply(lambda x: x.min_salary*2 if x.hourly ==1 else x.min_salary, axis =1)
df1['max_salary'] = df1.apply(lambda x: x.max_salary*2 if x.hourly ==1 else x.max_salary, axis =1)

# %%
df1
# Out:
#                                              Job Title  \
# 0                                       Data Scientist
# 1                            Healthcare Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 950           Sr Scientist, Immuno-Oncology - Oncology
# 951                               Senior Data Engineer
# 952  Project Scientist - Auton Lab, Robotics Institute
# 953                               Data Science Manager
# 955          Research Scientist – Security and Privacy
#
#                                        Job Description  Rating  \
# 0    Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1    What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2    KnowBe4, Inc. is a high growth information sec...     4.8
# ...

# %%
df1['company_txt'] = df.company_txt.apply(lambda x: x.replace('\n', ''))

# %%
df1['company_txt']
# Out:
# 0                          Tecolote Research
# 1      University of Maryland Medical System
# 2                                    KnowBe4
# 3                                       PNNL
# 4                         Affinity Solutions
#                        ...
# 950                                      GSK
# 951                               Eventbrite
# 952           Software Engineering Institute
# 953                             Numeric, LLC
# 955             Riverside Research Institute
# Name: company_txt, Length: 731, dtype: object

# %%
df1.avg_salary.hist()
# Out:
# <AxesSubplot:>

# %%
df1.age.hist()
# Out:
# <AxesSubplot:>

# %%
df1[['age','avg_salary','Rating']].corr()
# Out:
#                  age  avg_salary    Rating
# age         1.000000    0.031889 -0.076928
# avg_salary  0.031889    1.000000  0.133678
# Rating     -0.076928    0.133678  1.000000

# %%
df1['num_comp'] = df1['Competitors'].apply(lambda x: len(x.split(',')) if x != '-1' else 0)

# %%
import seaborn as sns
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(df1[['age','avg_salary','Rating','num_comp']].corr(),vmax=.3, center=0, cmap=cmap,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
pd.pivot_table(df1, index = 'job_rename', values = 'avg_salary')
# Out:
#                 avg_salary
# job_rename
# analyst          65.857843
# data engineer   105.403361
# data scientist  116.811594
# director        168.607143
# manager          84.022727
# mle             126.431818
# na               83.383523

# %%
pd.pivot_table(df1, index = ['job_rename','seniority'], values = 'avg_salary')
# Out:
#                           avg_salary
# job_rename     seniority
# analyst        jr          56.500000
#                na          61.155405
#                senior      79.092593
# data engineer  na          96.701220
#                senior     124.689189
# data scientist jr         106.500000
#                na         107.024324
#                senior     137.044444
# director       na         168.607143
# manager        na          84.022727
# mle            na         119.133333
#                senior     142.071429
# na             na          72.512195
#                senior     108.613208

# %%
pd.pivot_table(df1, index = ['job_state','job_rename'], values = 'avg_salary').sort_values('job_state', ascending = False)
# Out:
#                           avg_salary
# job_state job_rename
#  WI       na               54.000000
#           data scientist  113.500000
#           analyst          58.833333
#  WA       na               97.500000
#           data scientist   99.764706
# ...                              ...
#  AZ       analyst          55.000000
#           na              124.500000
#  AL       na               43.750000
#           data engineer    65.000000
#           analyst          62.200000
#
# [115 rows x 1 columns]

# %%
pd.pivot_table(df1, index = ['job_state','job_rename'], values = 'avg_salary', aggfunc = 'count').sort_values('job_state', ascending = False)
# Out:
#                           avg_salary
# job_state job_rename
#  WI       na                       4
#           data scientist           3
#           analyst                  3
#  WA       na                       1
#           data scientist          17
# ...                              ...
#  AZ       analyst                  1
#           na                       2
#  AL       na                       2
#           data engineer            1
#           analyst                  5
#
# [115 rows x 1 columns]

# %%
pd.pivot_table(df1[df1.job_rename == 'data scientist'], index = 'job_state', values = 'avg_salary').sort_values('avg_salary', ascending = False)
# Out:
#               avg_salary
# job_state
#  DC           149.000000
#  CA           140.523077
#  UT           140.500000
#  MO           127.666667
#  IL           117.233333
#  NC           117.000000
#  NY           115.371795
#  MA           113.750000
#  WI           113.500000
#  PA           113.333333
#  MD           109.115385
#  CO           108.666667
#  VA           108.416667
#  Los Angeles  107.500000
#  NJ           106.875000
#  MI           106.625000
#  OH           105.285714
#  TX           100.730769
#  WA            99.764706
#  OR            98.500000
#  FL            97.357143
#  TN            96.000000
#  IN            84.500000
#  KY            84.000000
#  CT            84.000000
#  GA            81.333333
#  NM            74.333333
#  AZ            69.500000

# %%
df1.columns
# Out:
# Index(['Job Title', 'Job Description', 'Rating', 'Company Name', 'Location',
#        'Headquarters', 'Size', 'Founded', 'Type of ownership', 'Industry',
#        'Sector', 'Revenue', 'Competitors', 'hourly', 'employer_provided',
#        'min_salary', 'max_salary', 'avg_salary', 'job_state', 'age',
#        'python_yn', 'R_yn', 'spark', 'aws', 'excel', 'job_rename', 'seniority',
#        'company_txt', 'num_comp'],
#       dtype='object')

# %%
df_pivots = df1[['Rating', 'Industry', 'Sector', 'Revenue', 'num_comp', 'hourly', 'employer_provided', 'python_yn', 'R_yn', 'spark', 'aws', 'excel', 'Type of ownership','avg_salary']]

# %%
pd.pivot_table(df1, index = 'Revenue', columns = 'python_yn', values = 'avg_salary', aggfunc = 'count')
# Out:
# python_yn                          0    1
# Revenue
# $1 to $2 billion (USD)            16   44
# $1 to $5 million (USD)             1    7
# $10 to $25 million (USD)          16   16
# $10+ billion (USD)                66   58
# $100 to $500 million (USD)        47   44
# $2 to $5 billion (USD)            17   22
# $25 to $50 million (USD)          24   16
# $5 to $10 billion (USD)            9   10
# $5 to $10 million (USD)            9    7
# $50 to $100 million (USD)         21   25
# $500 million to $1 billion (USD)  29   28
# Less than $1 million (USD)         1    3
# Unknown / Non-Applicable          87  108

# %%
import nltk
import matplotlib.pyplot as plt
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\pmaheria\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\pmaheria\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS#Credit KenJee Youtube channel
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
words = " ".join(df['Job Description'])

def punctuation_stop(text):
    """remove punctuation and stop words"""
    filtered = []
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    for w in word_tokens:
        if w not in stop_words and w.isalpha():
            filtered.append(w.lower())
    return filtered


words_filtered = punctuation_stop(words)

text = " ".join([ele for ele in words_filtered])

wc= WordCloud(background_color="white", random_state=1,stopwords=STOPWORDS, max_words = 2000, width =800, height = 1500)
wc.generate(text)

plt.figure(figsize=[10,10])
plt.imshow(wc,interpolation="bilinear")
plt.axis('off')
plt.show()
